# %%
import pandas as pd
import numpy as np

from datetime import datetime

# %%
normal_a = pd.read_csv("data/normal_mixed_1549901031015048.csv")

# normal_a = pd.read_csv("data/normal_longitudinal_acceleration_1549908723215048.csv")

# %%
normal_a.head()
# Out:
#    Unnamed: 0         timestamp   accel_x   accel_y   accel_z  gyro_roll  \
# 0           0  1549901031015048  0.021258  0.072019  0.757077   0.002319
# 1           1  1549901031065048  0.028152  0.019107  0.750582   0.004978
# 2           2  1549901031115048  0.035621  0.055852  0.753566   0.017208
# 3           3  1549901031165048  0.051708  0.116113  0.748827   0.004966
# 4           4  1549901031215048  0.072966  0.055852  0.756550   0.000177
#
#    gyro_pitch  gyro_yaw  label
# 0    0.001862  0.017807      0
# 1   -0.000798  0.032158      0
# 2    0.002926  0.020442      0
# 3   -0.003990  0.024154      0
# 4    0.001331  0.026801      0

# %%
normal_a.describe()
# Out:
#          Unnamed: 0     timestamp       accel_x       accel_y       accel_z  \
# count  10143.000000  1.014300e+04  10143.000000  10143.000000  10143.000000
# mean    5071.000000  1.549901e+15      0.027469      0.072955      0.752117
# std     2928.176224  1.464289e+08      0.048772      0.083715      0.003813
# min        0.000000  1.549901e+15     -1.132734     -0.566306      0.720741
# 25%     2535.500000  1.549901e+15      0.012353      0.032335      0.750406
# 50%     5071.000000  1.549901e+15      0.031025      0.076429      0.752162
# 75%     7606.500000  1.549901e+15      0.050559      0.120522      0.753741
# max    10142.000000  1.549902e+15      0.392407      0.664340      0.784986
#
#           gyro_roll    gyro_pitch      gyro_yaw    label
# count  10143.000000  10143.000000  10143.000000  10143.0
# mean      -0.000924      0.000317     -0.034139      0.0
# std        0.017493      0.017878      0.142163      0.0
# ...

# %%
# Convert Unix time to DateTime object; Unit: microseconds

normal_a["datetime"] = pd.to_datetime(normal_a['timestamp'], unit='us')

# %%
normal_a.head()
# Out:
#    Unnamed: 0         timestamp   accel_x   accel_y   accel_z  gyro_roll  \
# 0           0  1549901031015048  0.021258  0.072019  0.757077   0.002319
# 1           1  1549901031065048  0.028152  0.019107  0.750582   0.004978
# 2           2  1549901031115048  0.035621  0.055852  0.753566   0.017208
# 3           3  1549901031165048  0.051708  0.116113  0.748827   0.004966
# 4           4  1549901031215048  0.072966  0.055852  0.756550   0.000177
#
#    gyro_pitch  gyro_yaw  label                   datetime     accel  delta_t  \
# 0    0.001862  0.017807      0 2019-02-11 16:03:51.015048  0.760791      NaN
# 1   -0.000798  0.032158      0 2019-02-11 16:03:51.065048  0.751353     0.05
# 2    0.002926  0.020442      0 2019-02-11 16:03:51.115048  0.756472     0.05
# 3   -0.003990  0.024154      0 2019-02-11 16:03:51.165048  0.759537     0.05
# 4    0.001331  0.026801      0 2019-02-11 16:03:51.215048  0.762110     0.05
#
#     delta_a      jerk
# 0       NaN       NaN
# ...

# %%
# calc accelleration

normal_a["accel"] = np.sqrt(pow(normal_a.accel_x, 2) + pow(normal_a.accel_y, 2) + pow(normal_a.accel_z, 2))

# %%
normal_a.head()
# Out:
#    Unnamed: 0         timestamp   accel_x   accel_y   accel_z  gyro_roll  \
# 0           0  1549901031015048  0.021258  0.072019  0.757077   0.002319
# 1           1  1549901031065048  0.028152  0.019107  0.750582   0.004978
# 2           2  1549901031115048  0.035621  0.055852  0.753566   0.017208
# 3           3  1549901031165048  0.051708  0.116113  0.748827   0.004966
# 4           4  1549901031215048  0.072966  0.055852  0.756550   0.000177
#
#    gyro_pitch  gyro_yaw  label                   datetime     accel  delta_t  \
# 0    0.001862  0.017807      0 2019-02-11 16:03:51.015048  0.760791      NaN
# 1   -0.000798  0.032158      0 2019-02-11 16:03:51.065048  0.751353     0.05
# 2    0.002926  0.020442      0 2019-02-11 16:03:51.115048  0.756472     0.05
# 3   -0.003990  0.024154      0 2019-02-11 16:03:51.165048  0.759537     0.05
# 4    0.001331  0.026801      0 2019-02-11 16:03:51.215048  0.762110     0.05
#
#     delta_a      jerk
# 0       NaN       NaN
# ...

# %%
# Mean acceleration values per driver event type (example: aggressive bump) and per label;

normal_a[["label", "accel"]].groupby("label").mean()
# Out:
#           accel
# label
# 0      0.762132

# %%
normal_a.head()
# Out:
#    Unnamed: 0         timestamp   accel_x   accel_y   accel_z  gyro_roll  \
# 0           0  1549901031015048  0.021258  0.072019  0.757077   0.002319
# 1           1  1549901031065048  0.028152  0.019107  0.750582   0.004978
# 2           2  1549901031115048  0.035621  0.055852  0.753566   0.017208
# 3           3  1549901031165048  0.051708  0.116113  0.748827   0.004966
# 4           4  1549901031215048  0.072966  0.055852  0.756550   0.000177
#
#    gyro_pitch  gyro_yaw  label                   datetime     accel  delta_t  \
# 0    0.001862  0.017807      0 2019-02-11 16:03:51.015048  0.760791      NaN
# 1   -0.000798  0.032158      0 2019-02-11 16:03:51.065048  0.751353     0.05
# 2    0.002926  0.020442      0 2019-02-11 16:03:51.115048  0.756472     0.05
# 3   -0.003990  0.024154      0 2019-02-11 16:03:51.165048  0.759537     0.05
# 4    0.001331  0.026801      0 2019-02-11 16:03:51.215048  0.762110     0.05
#
#     delta_a      jerk
# 0       NaN       NaN
# ...

# %%
normal_a["delta_a"] = normal_a["accel"].diff()

# %%
# diff returns a timedelta object; converts to microseconds
normal_a["delta_t"] = normal_a["datetime"].diff().dt.microseconds

# convert to seconds
normal_a["delta_t"] = normal_a["delta_t"] / 1E6

# %%
normal_a["delta_t"].head()
# Out:
# 0     NaN
# 1    0.05
# 2    0.05
# 3    0.05
# 4    0.05
# Name: delta_t, dtype: float64

# %%
normal_a["jerk"] = normal_a.delta_a/normal_a.delta_t

# %%
min(normal_a.datetime)
# Out:
# Timestamp('2019-02-11 16:03:51.015048')

# %%
max(normal_a.datetime)
# Out:
# Timestamp('2019-02-11 16:12:18.165048')

# %%
# get the maximum 

idx = normal_a['jerk'].idxmax()
print(idx, normal_a["jerk"][idx] )

print(normal_a.loc[idx]['datetime'])
print(normal_a.loc[idx]['jerk'])
# Out:
# 2567 5.005857398018043
# 2019-02-11 16:05:59.365048
# 5.005857398018043
