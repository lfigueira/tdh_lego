# %%
import pandas as pd
import numpy as np
import glob

from os.path import basename
from datetime import datetime

# %%
ifolder = "../data/"

ifiles = [f for f in glob.glob(ifolder + "*.csv", recursive=True)]

# not all files have the same columns, so specify which to import 
csv_cols = ["timestamp", "accel_x", "accel_y", "accel_z", "gyro_roll", "gyro_pitch", "gyro_yaw", "label"]

# array of dataframes; used to merge the data from all dataframes
df_array = []

# iterate input files 
for ifile in ifiles:
    
    # used to identify data source
    fname = basename(ifile).split('.')[0]
    print(fname)

    #with open(ifile) as csv_file:  
    data = pd.read_csv(ifile, usecols = csv_cols)
    data["data_source"] = fname
    
    # data transformation
    # Convert Unix time to DateTime object; Unit: microseconds
    data["datetime"] = pd.to_datetime(data['timestamp'], unit='us')

    # making sure the rows are sequential 
    data.sort_values(by="datetime", ascending=True, inplace=True)

    # calc scalar accelleration
    data["accel"] = np.sqrt(pow(data.accel_x, 2) + pow(data.accel_y, 2) + pow(data.accel_z, 2))

    # calc jerk

    # diff returns a timedelta object; converts to microseconds
    data["delta_t"] = data["datetime"].diff().dt.microseconds

    # convert delta_t to seconds
    data["delta_t"] = data["delta_t"] / 1E6

    # delta acceleration 
    data["delta_a"] = data["accel"].diff()

    data["jerk"] = data.delta_a/data.delta_t

    df_array.append(data)
# Out:
# normal_longitudinal_acceleration_1549908723215048
#           timestamp   accel_x   accel_y   accel_z  gyro_roll  gyro_pitch  \
# 0  1549908723215048  0.027003  0.158736  0.753566   0.019349   -0.015032
# 1  1549908723265048  0.047686  0.277788  0.757603  -0.019485   -0.004387
# 2  1549908723315048  0.023556  0.223406  0.746896  -0.006711   -0.012363
# 3  1549908723365048  0.053432  0.191071  0.756023   0.006588    0.005726
# 4  1549908723415048  0.037919  0.160206  0.744438  -0.001393   -0.029378
#
#    gyro_yaw  label                                        data_source
# 0  0.044264      0  normal_longitudinal_acceleration_1549908723215048
# 1  0.067111      0  normal_longitudinal_acceleration_1549908723215048
# 2  0.090479      0  normal_longitudinal_acceleration_1549908723215048
# 3  0.121281      0  normal_longitudinal_acceleration_1549908723215048
# 4  0.159513      0  normal_longitudinal_acceleration_1549908723215048
# aggressive_bump_1550163148318484
#           timestamp   accel_x   accel_y   accel_z  gyro_roll  gyro_pitch  \
# 0  1550163148318484  0.033898  0.077898  0.749529  -0.000423   -0.000528
# 1  1550163148368484  0.032748  0.077898  0.749353  -0.000423   -0.000528
# 2  1550163148418484  0.034472  0.080838  0.749880  -0.000954    0.000004
# 3  1550163148468484  0.033898  0.080838  0.749002  -0.000422   -0.000528
# 4  1550163148518484  0.033898  0.080838  0.749353  -0.000422   -0.000527
#
#    gyro_yaw  label                       data_source
# 0  0.000076      0  aggressive_bump_1550163148318484
# 1  0.000076      0  aggressive_bump_1550163148318484
# 2  0.000076      0  aggressive_bump_1550163148318484
# 3 -0.000456      0  aggressive_bump_1550163148318484
# 4 -0.000455      0  aggressive_bump_1550163148318484
# aggressive_turn_1549625320507325
#           timestamp   accel_x   accel_y   accel_z  gyro_roll  gyro_pitch  \
# 0  1549625320507325  0.072391  0.136689  0.751811  -0.000675   -0.000289
# 1  1549625320557325  0.071817  0.135220  0.751460  -0.000675   -0.000288
# 2  1549625320607325  0.074115  0.133750  0.751460  -0.000675   -0.000288
# 3  1549625320657325  0.073540  0.138159  0.751811  -0.000674   -0.000288
# 4  1549625320707325  0.072391  0.141099  0.751811  -0.000674   -0.000820
#
#    gyro_yaw  label                       data_source
# 0 -0.003120      0  aggressive_turn_1549625320507325
# 1 -0.003651      0  aggressive_turn_1549625320507325
# 2 -0.004181      0  aggressive_turn_1549625320507325
# 3 -0.003647      0  aggressive_turn_1549625320507325
# 4 -0.004177      0  aggressive_turn_1549625320507325
# normal_turn_1549626293857325
#           timestamp   accel_x   accel_y   accel_z  gyro_roll  gyro_pitch  \
# 0  1549626293857325  0.074115  0.146978  0.753566  -0.010867    0.000940
# 1  1549626293907325  0.058028  0.102885  0.749529   0.002435   -0.003315
# 2  1549626293957325  0.083882  0.126401  0.750406  -0.000226    0.010514
# 3  1549626294007325  0.095373  0.104354  0.751108  -0.007672    0.007850
# 4  1549626294057325  0.099969  0.130810  0.749353  -0.000754    0.004123
#
#    gyro_yaw  label                   data_source
# 0  0.023139      0  normal_turn_1549626293857325
# 1  0.014086      0  normal_turn_1549626293857325
# 2  0.009292      0  normal_turn_1549626293857325
# 3  0.019925      0  normal_turn_1549626293857325
# 4  0.019915      0  normal_turn_1549626293857325
# aggressive_longitudinal_acceleration_1549653321089461
#           timestamp   accel_x   accel_y   accel_z  gyro_roll  gyro_pitch  \
# 0  1549653321089461  0.051708  0.054382  0.749002   0.000225    0.000219
# 1  1549653321139461  0.052857  0.054382  0.748827   0.000225    0.000219
# 2  1549653321189461  0.053432  0.057321  0.750231   0.000225   -0.000313
# 3  1549653321239461  0.052283  0.055852  0.748651  -0.000307    0.000219
# 4  1549653321289461  0.052283  0.057321  0.748827  -0.000307    0.000218
#
#    gyro_yaw  label                                        data_source
# 0 -0.000349      0  aggressive_longitudinal_acceleration_154965332...
# 1 -0.000348      0  aggressive_longitudinal_acceleration_154965332...
# 2  0.000184      0  aggressive_longitudinal_acceleration_154965332...
# 3  0.000715      0  aggressive_longitudinal_acceleration_154965332...
# 4 -0.000349      0  aggressive_longitudinal_acceleration_154965332...
# normal_mixed_1549901031015048
#           timestamp   accel_x   accel_y   accel_z  gyro_roll  gyro_pitch  \
# 0  1549901031015048  0.021258  0.072019  0.757077   0.002319    0.001862
# 1  1549901031065048  0.028152  0.019107  0.750582   0.004978   -0.000798
# 2  1549901031115048  0.035621  0.055852  0.753566   0.017208    0.002926
# 3  1549901031165048  0.051708  0.116113  0.748827   0.004966   -0.003990
# 4  1549901031215048  0.072966  0.055852  0.756550   0.000177    0.001331
#
#    gyro_yaw  label                    data_source
# 0  0.017807      0  normal_mixed_1549901031015048
# 1  0.032158      0  normal_mixed_1549901031015048
# 2  0.020442      0  normal_mixed_1549901031015048
# 3  0.024154      0  normal_mixed_1549901031015048
# 4  0.026801      0  normal_mixed_1549901031015048
# normal_mixed_1550054269957615
#           timestamp   accel_x   accel_y   accel_z  gyro_roll  gyro_pitch  \
# 0  1550054269957615  0.016087  0.060261  0.752513  -0.000117    0.000136
# 1  1550054270007615  0.015512  0.064670  0.751986  -0.000117    0.000136
# 2  1550054270057615  0.015512  0.061731  0.751460  -0.000649   -0.000396
# 3  1550054270107615  0.018960  0.061731  0.751811  -0.000117   -0.000395
# 4  1550054270157615  0.018385  0.058791  0.752513  -0.000117    0.000137
#
#    gyro_yaw  label                    data_source
# 0 -0.000610      0  normal_mixed_1550054269957615
# 1 -0.000078      0  normal_mixed_1550054269957615
# 2 -0.000078      0  normal_mixed_1550054269957615
# 3 -0.000609      0  normal_mixed_1550054269957615
# 4 -0.000077      0  normal_mixed_1550054269957615

# %%
# concatenate all dataframes; the index needs to be reset 
df = pd.concat(df_array).reset_index(drop=True)

# %%
df.head()
# Out:
#           timestamp   accel_x   accel_y   accel_z  gyro_roll  gyro_pitch  \
# 0  1549908723215048  0.027003  0.158736  0.753566   0.019349   -0.015032
# 1  1549908723265048  0.047686  0.277788  0.757603  -0.019485   -0.004387
# 2  1549908723315048  0.023556  0.223406  0.746896  -0.006711   -0.012363
# 3  1549908723365048  0.053432  0.191071  0.756023   0.006588    0.005726
# 4  1549908723415048  0.037919  0.160206  0.744438  -0.001393   -0.029378
#
#    gyro_yaw  label                                        data_source  \
# 0  0.044264      0  normal_longitudinal_acceleration_1549908723215048
# 1  0.067111      0  normal_longitudinal_acceleration_1549908723215048
# 2  0.090479      0  normal_longitudinal_acceleration_1549908723215048
# 3  0.121281      0  normal_longitudinal_acceleration_1549908723215048
# 4  0.159513      0  normal_longitudinal_acceleration_1549908723215048
#
#                     datetime     accel  delta_t   delta_a      jerk
# 0 2019-02-11 18:12:03.215048  0.770576      NaN       NaN       NaN
# 1 2019-02-11 18:12:03.265048  0.808333     0.05  0.037757  0.755142
# 2 2019-02-11 18:12:03.315048  0.779948     0.05 -0.028386 -0.567714
# 3 2019-02-11 18:12:03.365048  0.781623     0.05  0.001675  0.033506
# 4 2019-02-11 18:12:03.415048  0.762425     0.05 -0.019198 -0.383959

# %%
# Mean acceleration values per driver event type (example: aggressive bump) and per label;

grouped = df[["data_source", "label", "accel"]].groupby(["data_source", "label"]).mean()

# %%
grouped
# Out:
#                                                              accel
# data_source                                        label
# aggressive_bump_1550163148318484                   0      0.797093
#                                                    1      0.956922
# aggressive_longitudinal_acceleration_1549653321... 0      0.760171
#                                                    1      0.825468
# aggressive_turn_1549625320507325                   0      0.768733
#                                                    1      0.832888
# normal_longitudinal_acceleration_1549908723215048  0      0.763528
# normal_mixed_1549901031015048                      0      0.762132
# normal_mixed_1550054269957615                      0      0.762704
# normal_turn_1549626293857325                       0      0.763334

# %%
# get the maximum 

idx = df['jerk'].idxmax()

print(idx)

print(idx, df["jerk"][idx] )
print(df.head())


print(df.loc[idx]['datetime'])

print(df.loc[idx]['jerk'])
# Out:
# 20769
# 20769 52.769725244872326
#           timestamp   accel_x   accel_y   accel_z  gyro_roll  gyro_pitch  \
# 0  1549908723215048  0.027003  0.158736  0.753566   0.019349   -0.015032
# 1  1549908723265048  0.047686  0.277788  0.757603  -0.019485   -0.004387
# 2  1549908723315048  0.023556  0.223406  0.746896  -0.006711   -0.012363
# 3  1549908723365048  0.053432  0.191071  0.756023   0.006588    0.005726
# 4  1549908723415048  0.037919  0.160206  0.744438  -0.001393   -0.029378
#
#    gyro_yaw  label                                        data_source  \
# 0  0.044264      0  normal_longitudinal_acceleration_1549908723215048
# 1  0.067111      0  normal_longitudinal_acceleration_1549908723215048
# 2  0.090479      0  normal_longitudinal_acceleration_1549908723215048
# 3  0.121281      0  normal_longitudinal_acceleration_1549908723215048
# 4  0.159513      0  normal_longitudinal_acceleration_1549908723215048
#
#                     datetime     accel  delta_t   delta_a      jerk
# 0 2019-02-11 18:12:03.215048  0.770576      NaN       NaN       NaN
# 1 2019-02-11 18:12:03.265048  0.808333     0.05  0.037757  0.755142
# 2 2019-02-11 18:12:03.315048  0.779948     0.05 -0.028386 -0.567714
# 3 2019-02-11 18:12:03.365048  0.781623     0.05  0.001675  0.033506
# 4 2019-02-11 18:12:03.415048  0.762425     0.05 -0.019198 -0.383959
# 2019-02-14 16:58:41.218484
# aaa
# 52.769725244872326
